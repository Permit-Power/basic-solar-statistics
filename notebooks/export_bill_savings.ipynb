# %% [markdown]
# ### Export dGen-produced bill savings
# This notebook aggregates dGen-produced solar bill savings so the monthly github action can run without using the local drive

# %%
import sys
from pathlib import Path
sys.path.append("../src")

from bill_savings_export import export_state_bill_savings_to_csv

# %%
export_state_bill_savings_to_csv(
    base_directory="/Volumes/Seagate Portabl/permit_power/dgen_runs/per_state_outputs",
    run_name="run_all_states_net_savings_adjust_loan_params",
    export_directory="../data/bill_savings_csvs",
)
# Out:
# '/Users/talorgruenwald/src/permit_power/basic-solar-statistics/data/bill_savings_csvs/run_all_states_net_savings_adjust_loan_params_state_bill_savings.csv'
